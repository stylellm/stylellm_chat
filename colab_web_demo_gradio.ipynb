# %% [markdown]
# 🎯 **运行Demo需要GPU支持，在Colab "更改运行时类型"中选择"T4 GPU"来使用免费GPU。**

# %% [markdown]
# # 安装依赖

# %%
! git clone https://github.com/stylellm/stylellm_chat.git
# %cd stylellm_chat
! pip -q install -r requirements.txt
# Out:
# Cloning into 'stylellm_chat'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 31 (delta 8), reused 25 (delta 5), pack-reused 0
# Receiving objects: 100% (31/31), 13.47 KiB | 13.47 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/stylellm_chat
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.9/312.9 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 54.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 85.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 创建StyleLLMChat实例

# %%
# @title 以"水浒传+鲁智深"风格为例，修改`scene`和`character`参数可以使用其他角色风格。
from stylellm_chat import StyleLLMChat, QwenChatModel, StyleModel
sc = StyleLLMChat(
    chat_model=QwenChatModel(model_name_or_path="Qwen/Qwen1.5-7B-Chat-AWQ", device="cuda"),
    style_model=StyleModel(model_name_or_path="stylellm/ShuiHuZhuan-6b-AWQ", device="cuda",
                            scene="水浒传", character="鲁智深")
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # 启动Web UI

# %%
# @title Gradio启动后可在colab中直接对话，也打开public URL 在外部浏览器中对话
import web_demo_gradio
demo = web_demo_gradio.run_app(sc)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://89ca650c564d223511.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://89ca650c564d223511.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
